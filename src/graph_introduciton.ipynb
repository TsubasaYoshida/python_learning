# %%
'''
『詳細! Python 3 入門ノート』(https://www.amazon.co.jp/dp/4800711673)
Section 14-1 基本的なグラフの書き方
'''
# Out:
# '\n『詳細! Python 3 入門ノート』(https://www.amazon.co.jp/dp/4800711673)\nSection 14-1 基本的なグラフの書き方\n'

# %%
import matplotlib.pyplot as plt
data = [2., 2.3, 4.1, 2.4, 5.3, 3.2, 4.6]
plt.plot(data)
plt.show()

# %%
price = [200, 300, 400, 500, 600]
count = [31, 29, 25, 28, 26]
plt.plot(price, count, marker="o")
plt.title("count - price")
plt.xlabel("price")
plt.ylabel("count")
plt.grid(True)
plt.show()

# %%
import math
X = range(0, 360) # rangeメソッドは整数の連番を作る(https://note.nkmk.me/python-range-usage/)
Y = [math.sin(math.radians(d)) for d in X] # 後置ｆｏｒは内包表記と言うらしい(https://qiita.com/y__sama/items/a2c458de97c4aa5a98e7)
plt.plot(X, Y)
plt.show()

# %%
X = range(0, 360)
S = [math.sin(math.radians(d)) for d in X]
C = [math.cos(math.radians(d)) for d in X]
plt.plot(X, S)
plt.plot(X, C)
plt.show()
